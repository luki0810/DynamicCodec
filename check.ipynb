# %%
from fairseq import checkpoint_utils

ckpt_path = "/data/L202500019/DynamicCodec/ckpt/hubert_large_ll60k.pt"
models, cfg, task = checkpoint_utils.load_model_ensemble_and_task([ckpt_path])

print("📦 加载的模型数量:", len(models))
print("🧠 模型结构:")
print(models[0])  # 查看模型结构

print("\n⚙️ 配置:")
print(cfg)

print("\n🎯 任务类型:", type(task))
print(task)
# Out:
# 2025-12-13 14:44:12 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[2], line 4
#       1 from fairseq import checkpoint_utils
#       3 ckpt_path = "/mnt/speech/luyongkang/models/hubert/hubert_large_ll60k.pt"
# ----> 4 models, cfg, task = checkpoint_utils.load_model_ensemble_and_task([ckpt_path])
#       6 print("📦 加载的模型数量:", len(models))
#       7 print("🧠 模型结构:")
#
# File /data/L202500019/anaconda3/envs/dynamic/lib/python3.9/site-packages/fairseq/checkpoint_utils.py:423, in load_model_ensemble_and_task(filenames, arg_overrides, task, strict, suffix, num_shards, state)
#     418 filename = get_maybe_sharded_checkpoint_filename(
#     419     orig_filename, suffix, shard_idx, num_shards
#     420 )
#     422 if not PathManager.exists(filename):
# ...

# %%
import argparse
import os
from pathlib import Path
from typing import Tuple, List, Optional

import numpy as np
import torch
import yaml
from tqdm import tqdm

ALL_MODELS = {
    "data2vec_base_l6": 768,
    "data2vec_large_l18": 1024,
    "hubert_base_l9": 768,
    "hubert_large_l18": 1024,
    "whisper_medium_l24": 1024,
    "whisper_large_l32": 1280
}

file__ = "/mnt/speech/luyongkang/RepCodec/repcodec/tokenize.py"

def load_model(model_path: str, config_path: Optional[str] = None):
    if config_path is None:
        name = os.path.basename(model_path).strip(".pkl")
        assert name in ALL_MODELS.keys(), f"Cannot find configs for {model_path}. " \
                                          f"Please provide the config file you used for training."
        config = os.path.join(os.path.dirname(file__), "configs", f"repcodec_dim{ALL_MODELS[name]}.yaml")
        with open(config) as fp:
            conf = yaml.load(fp, Loader=yaml.FullLoader)
    else:
        with open(config_path) as fp:
            conf = yaml.load(fp, Loader=yaml.FullLoader)["model_params"]
            
    for k in conf.keys():
        print(k,"    ",conf[k])
            
            
            
            
load_model(model_path="/mnt/speech/luyongkang/models/repcodec/hubert_large_l18.pkl")
# Out:
# input_channels      1024
# output_channels      1024
# encode_channels      1024
# decode_channels      1024
# code_dim      1024
# codebook_num      1
# codebook_size      1024
# bias      True
# enc_ratios      [1, 1]
# dec_ratios      [1, 1]
# enc_strides      [1, 1]
# dec_strides      [1, 1]
# enc_kernel_size      3
# dec_kernel_size      3
# enc_block_dilations      [1, 1]
# enc_block_kernel_size      3
# dec_block_dilations      [1, 1]
# dec_block_kernel_size      3

# %%
from audiotools import AudioSignal
import torch
signal = AudioSignal(torch.randn(44100), 44100)
res = signal.stft()
res.shape
# Out:
# torch.Size([1, 1, 1025, 87])

# %%
import torch

from model.vocoder.vocos.pretrained import Vocos

vocos = Vocos.from_pretrained("charactr/vocos-mel-24khz")

mel = torch.randn(1, 100, 256)  # B, C, T
audio = vocos.decode(mel)
# Out:
# '[Errno 101] Network is unreachable' thrown while requesting HEAD https://huggingface.co/charactr/vocos-mel-24khz/resolve/main/config.yaml
# Retrying in 1s [Retry 1/5].
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 5
#       1 import torch
#       3 from model.vocoder.vocos.pretrained import Vocos
# ----> 5 vocos = Vocos.from_pretrained("charactr/vocos-mel-24khz")
#       7 mel = torch.randn(1, 100, 256)  # B, C, T
#       8 audio = vocos.decode(mel)
#
# File /data/L202500019/DynamicCodec/model/vocoder/vocos/pretrained.py:162, in Vocos.from_pretrained(cls, repo_id, revision)
#     157 @classmethod
#     158 def from_pretrained(cls, repo_id: str, revision: Optional[str] = None) -> Vocos:
#     159     """
#     160     Class method to create a new Vocos model instance from a pre-trained model stored in the Hugging Face model hub.
#     161     """
# ...
